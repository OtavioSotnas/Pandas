# %% [markdown]
# # Conhecendo a base de dados

# %% [markdown]
# ## Importando dados

# %% [markdown]
# Principais funções para importar dados
#
# - **read_csv()**: Essa função é usada para ler arquivos CSV (Comma Separated Values), que são arquivos de texto que contêm dados separados por vírgulas. É possível passar diversos parâmetros para personalizar a leitura do csv, como delimitador, cabeçalho, tipo de encoding, entre outros.
#
# - **read_excel()**: Essa função é usada para ler arquivos do Excel (.xls ou .xlsx) e criar um DataFrame a partir dos dados.
#
# - **read_json()**: Essa função é usada para ler arquivos JSON (JavaScript Object Notation), que são arquivos de texto que contêm dados em formato de objeto JavaScript.
#
# - **read_html()**: Essa função é usada para ler tabelas HTML, que são estruturas de dados organizadas em formato de tabela em uma página da web.
#
# - **read_sql()**: Essa função é usada para ler dados de um banco de dados relacional, como o MySQL, PostgreSQL e SQL Server. O Pandas é capaz de importar dados de diferentes formas, permitindo ajustar parâmetros como a consulta, o nome da tabela e o tipo de dados das colunas.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Armazenando o arquivo csv da nuvem na memória local
url = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv"

# %%
# Comando para ler um csv tendo o parametro de um csv
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
# Por padrão a função read_csv usa o argumento sep="," porem nosso arquivo está separado por ; e devemos mudar.
pd.read_csv(url, sep=";")
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
# Agora só precisamos declarar nossa base de dados em uma variável 
dados = pd.read_csv(url, sep=";")

# %%
# O tipo de dado que criamos é um pandas Data Frame
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
# Função .head para imprimir apenas os primeiros elementos do data frame
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %% [markdown]
# ## Características gerias da base de dados

# %% [markdown]
# Resumo:
#
# - **DataFrame**: é uma tabela de dados bidimensional, semelhante a uma planilha do Excel, com colunas rotuladas e linhas numeradas.
#
# - **Series**: é uma estrutura de dados unidimensional que pode armazenar qualquer tipo de dados, rotulados com índices.
#
#
# - **df.shape**: retorna a dimensão do data frame.
#
# - **df.columns**: retorna os títulos das colunas do data frame.
#
# - **df.info()**: retorna um data frame contendo as colunas, quantas linhas Non-Null têm e o tipo da coluna.
#
# - **df["nome_da_coluna1"]**: para acessar uma coluna em específico é só abrir colchetes e inserir o nome da coluna.
#
# - **df[['nome_da_coluna1', 'nome_da_coluna2']]**: para acessar mais de uma coluna ao mesmo tempo é só passar uma lista com os nomes das colunas.

# %%
# Comando .shape retorna a dimensão do data frame (32960 linhas e 9 colunas).
dados.shape
# Out:
# (32960, 9)

# %%
# Comando .columns retorna os títulos das colunas do data frame.
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
# Comando .info() retorna um data frame contendo as colunas, quantas linhas Non-Null têm e o tipo da coluna.
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
# Para acessar uma coluna em específico é só abrir colchetes e inserir o nome da coluna.
dados["Tipo"].head(10)
# Out:
# 0                  Quitinete
# 1                       Casa
# 2    Conjunto Comercial/Sala
# 3                Apartamento
# 4                Apartamento
# 5                Apartamento
# 6                Apartamento
# 7         Casa de Condomínio
# 8         Casa de Condomínio
# 9    Conjunto Comercial/Sala
# Name: Tipo, dtype: object

# %%
# Para acessar mais de uma coluna ao mesmo tempo é só passar uma lista com os nomes das colunas.
dados[['Quartos', 'Valor']].head(10)
# Out:
#    Quartos    Valor
# 0        1   1700.0
# 1        2   7000.0
# 2        0   5200.0
# 3        1    800.0
# 4        1    800.0
# 5        3   1200.0
# 6        2   1300.0
# 7        5  22000.0
# 8        2   1000.0
# 9        0  35000.0

# %% [markdown]
# # Análise exploratória de dados

# %% [markdown]
# ## Qual o valor médio de aluguel por tipo de imóvel ?

# %% [markdown]
# Resumo:
#
# - **df.groupby("coluna")**: realiza um agrupamento por alguma coluna específica, essa função funciona em conjunto com sum() ou mean() para realizar o agrupamento.
#
# - **df.sort_values()**: ordena os valores em relação a um eixo.

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
# O comando groupby("Coluna") somente separa uma coluna do data frame, é necessário usar funções auxiliares como sum() ou mean() para sair os resultados.
dados.groupby("Tipo").mean(numeric_only=True).head() # A função mean() pega todas colunas inclusive as não numéricas, por isso o argumento "numeric_only=True"
# Out:
#                      Quartos     Vagas    Suites        Area         Valor  \
# Tipo
# Apartamento         2.481569  1.232388  0.875998  119.790498   4744.614648
# Box/Garagem         0.060976  1.304878  0.000000   17.524390   1899.756098
# Casa                3.133402  1.795243  1.258532  250.578077   6793.454922
# Casa Comercial      1.562264  2.203774  0.260377  372.241509  14478.264151
# Casa de Condomínio  4.007028  3.101406  2.864458  456.161647  11952.061245
#
#                      Condominio         IPTU
# Tipo
# Apartamento         1722.653697   686.170413
# Box/Garagem          305.450000   125.846154
# Casa                 931.280952  1582.506394
# Casa Comercial      1935.709677  1707.386740
# Casa de Condomínio  1342.025527  3252.517730

# %%
# Podemos aplicar o groupby e relacionar a apenas com uma ou mais colunas e ordenar usando o sort_values()
dados.groupby('Tipo')[["Valor"]].mean().sort_values("Valor")
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
dados_preco_tipo = dados.groupby('Tipo')[["Valor"]].mean().sort_values("Valor")

# %%
dados_preco_tipo.plot(kind="barh", figsize=(10,4), color="blue")
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ## Removendo os imóveis comerciais

# %% [markdown]
# Resumo:
#
# - **df["Coluna"].unique()**: retorna os valores unicos de uma coluna.
#
# - **df.query("expressão")**: filtra linhas em um data frame utlizando uma expressão booleana em formato de string. Para usarmos uma variável na expressão necessário botar @ antes.

# %%
# A função unique() retorna os valores unicos de uma coluna
dados["Tipo"].unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala', 
                      'Prédio Inteiro', 'Loja/Salão', 
                      'Galpão/Depósito/Armazém', 
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
# A função query() filtra linhas em um data frame utlizando uma expressão booleana em formato de string.
dados.query("@imoveis_comerciais in Tipo").head() # Para usarmos uma var na expressão necessário botar @ antes.
# Out:
#                        Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2   Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9   Conjunto Comercial/Sala           Centro        0      3       0   695
# 16           Prédio Inteiro         Botafogo        0      0       0   536
# 26  Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29               Loja/Salão     Campo Grande        0      1       0    35
#
#       Valor  Condominio    IPTU
# 2    5200.0      4020.0  1111.0
# 9   35000.0     19193.0  3030.0
# 16  28000.0         NaN  3563.0
# 26   1100.0       600.0     NaN
# 29   1300.0       950.0     NaN

# %%
# Assim separamos os dados em tipo comercial e não comercial para melhor visualização dos gráficos.
dados.query("@imoveis_comerciais not in Tipo").head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
dados_imoveis_comerciais = dados.query("@imoveis_comerciais in Tipo")
dados_imoveis_residenciais = dados.query("@imoveis_comerciais not in Tipo")

# %%
dados_imoveis_comerciais.groupby('Tipo')[["Valor"]].mean().sort_values("Valor").plot(kind="barh", figsize=(10,4), color="blue")
# Out:
# <Axes: ylabel='Tipo'>

# %%
dados_imoveis_residenciais.groupby('Tipo')[["Valor"]].mean().sort_values("Valor").plot(kind="barh", figsize=(10,4), color="blue")
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ## Qual o percentual de cada tipo de imóvel na nossa base de dados ?

# %% [markdown]
# Resumo:
#
# - **df[Series].value_counts()**: retorna uma series somando os valores únicos, para transformar em % passamos o argumento "normalize=True".
#
# - **df.to_frame()**: transforma uma series em um dataframe.
#
# - **df.rename(columns={'nome_antigo': 'novo_nome'}, inplace=True)**: permite especificar um dicionário que associa o nome antigo da coluna ao novo nome que queremos atribuir.

# %%
# value_counts() retorna uma series somando os valores únicos, para transformar em % passamos o argumento "normalize=True".
# to_frame() transforma uma series em um dataframe.
dados_percentual_tipo = dados_imoveis_residenciais['Tipo'].value_counts(normalize=True, ascending=True).to_frame()
dados_percentual_tipo
# Out:
#                     proportion
# Tipo
# Studio                0.000173
# Loft                  0.002207
# Casa de Vila          0.010774
# Flat                  0.020596
# Quitinete             0.036173
# Casa                  0.041842
# Casa de Condomínio    0.043096
# Apartamento           0.845139

# %%
dados_percentual_tipo.plot(kind="barh", figsize=(10,4), xlabel="Percentual", ylabel="Tipo", color="green")
# Out:
# <Axes: xlabel='Percentual', ylabel='Tipo'>

# %%
dados_apartamento = dados.query('Tipo == "Apartamento"')

# %%
dados_apartamento.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %%
# salvando o dataframe em uma variável
df_exemplo = dados['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')

# alterando o nome da coluna "Tipo" para "Percentuais"
df_exemplo.rename(columns={'proportion': 'Percentuais'}, inplace=True)

df_exemplo
# Out:
#                              Percentuais
# Tipo
# Apartamento                     0.592597
# Box/Garagem                     0.002488
# Casa                            0.029339
# Casa Comercial                  0.008040
# Casa de Condomínio              0.030218
# Casa de Vila                    0.007555
# Chácara                         0.000030
# Conjunto Comercial/Sala         0.206766
# Flat                            0.014442
# Galpão/Depósito/Armazém         0.018902
# Hotel                           0.000061
# Indústria                       0.000030
# Loft                            0.001547
# Loja Shopping/ Ct Comercial     0.007494
# Loja/Salão                      0.043265
# Loteamento/Condomínio           0.000152
# Pousada/Chalé                   0.000030
# Prédio Inteiro                  0.009132
# Quitinete                       0.025364
# Studio                          0.000121
# Sítio                           0.000303
# Terreno Padrão                  0.002124

# %% [markdown]
# # Tratando e filtrando dados

# %% [markdown]
# ## Lidando com dados nulos

# %% [markdown]
# Resumo:
#
# - **df.isnull()**: retorna um dataframe contendo True ou False onde True são os valores nulos na nossa base de dados.
#
# - **df.fillna()**: substitui todos os valores nulos usando um método específico ou substituindo por algum valor.
#
# - **df.dropna()**: remove todas as linhas ou colunas que possuem pelo menos um valor nulo.

# %%
# retorna um dataframe contendo True ou False onde True são os valores nulos na nossa base de dados.
dados_apartamento.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# 5      False   False    False  False   False  False  False        True   True
# 6      False   False    False  False   False  False  False       False  False
# 10     False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32951  False   False    False  False   False  False  False       False   True
# 32953  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
#
# [19532 rows x 9 columns]

# %%
dados_apartamento.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %%
# Substitui todos os valores nulos usando um método específico ou substituindo por algum valor.
dados_apartamento.fillna(value=0)
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   0.0
# ...

# %%
dados_apartamento.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %%
dados = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]],
                        columns = ['Local', 'Produto', 'Preço'])
dados
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
dados.query("Local == 'Supermercado'").index
# Out:
# Index([2, 5, 8], dtype='int64')

# %%
dados.drop(dados.query("Local == 'Supermercado'").index, axis=0)
# Out:
#      Local Produto  Preço
# 0    Feira  Cebola   2.50
# 1  Mercado  Cebola   1.99
# 3    Feira  Tomate   4.00
# 4  Mercado  Tomate   3.29
# 6    Feira  Batata   4.20
# 7  Mercado  Batata   3.99

# %% [markdown]
# ## Filtros

# %% [markdown]
# ### 1. Apartamentos que possuem 1 quarto e aluguel menor que 1200

# %%
# Usar operações com data frames retorna uma series de True ou False. 
selecao1 = dados_apartamento['Valor'] < 1200
selecao1
# Out:
# 3         True
# 4         True
# 5        False
# 6        False
# 10       False
#          ...
# 32951     True
# 32953     True
# 32956    False
# 32957    False
# 32958    False
# Name: Valor, Length: 19532, dtype: bool

# %%
# Para selecionarmos essas linhas da lógica acima é só passarmos a series dentro de um colchetes.
dados_apartamento[selecao1]
# Out:
#               Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                   Centro        1      0       0    15
# 4      Apartamento             Higienópolis        1      0       0    48
# 19     Apartamento  Freguesia (Jacarepaguá)        3      0       0    54
# 23     Apartamento                   Olaria        3      1       0    68
# 28     Apartamento                   Tijuca        1      0       0    48
# ...            ...                      ...      ...    ...     ...   ...
# 32925  Apartamento                 Campinho        2      0       0    63
# 32930  Apartamento  Freguesia (Jacarepaguá)        2      1       0    60
# 32950  Apartamento                   Tijuca        1      0       0    28
# 32951  Apartamento           Vila Valqueire        2      0       0    52
# 32953  Apartamento                    Méier        2      0       0    70
#
#         Valor  Condominio   IPTU
# 3       800.0       390.0   20.0
# ...

# %%
selecao2 = dados_apartamento['Quartos'] == 1
dados_apartamento[selecao2]
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3      Apartamento           Centro        1      0       0    15   800.0
# 4      Apartamento     Higienópolis        1      0       0    48   800.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 13     Apartamento       Copacabana        1      0       1    40  2000.0
# 28     Apartamento           Tijuca        1      0       0    48   750.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32918  Apartamento          Ipanema        1      0       0    55  2000.0
# 32922  Apartamento  Barra da Tijuca        1      1       0    62  1700.0
# 32935  Apartamento           Leblon        1      1       1    50  4300.0
# 32938  Apartamento       Copacabana        1      0       0    50  1950.0
# 32950  Apartamento           Tijuca        1      0       0    28  1000.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    NaN
# ...

# %%
# Para usarmos mais de uma lógica dentro do dataframe é só utilizarmos o '&' = 'and' e '|' = 'or', com as lógicas dentro de ().
dados_apartamento[(selecao1) & (selecao2)]
# Out:
#               Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3      Apartamento        Centro        1      0       0    15   800.0
# 4      Apartamento  Higienópolis        1      0       0    48   800.0
# 28     Apartamento        Tijuca        1      0       0    48   750.0
# 54     Apartamento        Centro        1      0       0    27   750.0
# 94     Apartamento        Centro        1      1       0    37  1100.0
# ...            ...           ...      ...    ...     ...   ...     ...
# 32627  Apartamento        Glória        1      0       0    46  1100.0
# 32643  Apartamento     Guadalupe        1      0       0    40   550.0
# 32666  Apartamento    Bonsucesso        1      0       0    60  1000.0
# 32714  Apartamento      Botafogo        1      0       0    21  1000.0
# 32950  Apartamento        Tijuca        1      0       0    28  1000.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    NaN
# 28          772.0   25.0
# ...

# %%
dados_apartamento_sel1 = dados_apartamento[(selecao1) | (selecao2)]

# %%
# Utilizando query
dados_apartamento.query('Quartos == 1 & Valor < 1200')
# Out:
#               Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3      Apartamento        Centro        1      0       0    15   800.0
# 4      Apartamento  Higienópolis        1      0       0    48   800.0
# 28     Apartamento        Tijuca        1      0       0    48   750.0
# 54     Apartamento        Centro        1      0       0    27   750.0
# 94     Apartamento        Centro        1      1       0    37  1100.0
# ...            ...           ...      ...    ...     ...   ...     ...
# 32627  Apartamento        Glória        1      0       0    46  1100.0
# 32643  Apartamento     Guadalupe        1      0       0    40   550.0
# 32666  Apartamento    Bonsucesso        1      0       0    60  1000.0
# 32714  Apartamento      Botafogo        1      0       0    21  1000.0
# 32950  Apartamento        Tijuca        1      0       0    28  1000.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    NaN
# 28          772.0   25.0
# ...

# %% [markdown]
# ### 2. Apartamentos que possuem pelo menos 2 quartos, aluguel menor que 3000 e area maior que 70

# %%
selecao = (dados_apartamento['Quartos'] >= 2) & (dados_apartamento['Valor'] < 3000) & (dados_apartamento["Area"] > 70)

# %%
dados_apartamento[selecao]
# Out:
#               Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 12     Apartamento       Lins de Vasconcelos        3      1       1    90
# 21     Apartamento                    Tijuca        2      1       0   110
# 24     Apartamento                    Tijuca        2      1       0    78
# 32     Apartamento                  Botafogo        2      1       0    76
# 36     Apartamento  Recreio dos Bandeirantes        3      1       1   105
# ...            ...                       ...      ...    ...     ...   ...
# 32934  Apartamento               Jacarepaguá        2      1       1    78
# 32940  Apartamento           Barra da Tijuca        2      1       1    85
# 32941  Apartamento           Barra da Tijuca        3      2       0    98
# 32944  Apartamento  Recreio dos Bandeirantes        3      2       1    88
# 32956  Apartamento               Jacarepaguá        3      1       2    78
#
#         Valor  Condominio   IPTU
# 12     1500.0       455.0   14.0
# ...

# %%
dados_apartamento_sel2 = dados_apartamento[selecao]

# %%
# Utilizando query
dados_apartamento.query('Quartos >= 2 & Valor < 3000 & Area > 70')
# Out:
#               Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 12     Apartamento       Lins de Vasconcelos        3      1       1    90
# 21     Apartamento                    Tijuca        2      1       0   110
# 24     Apartamento                    Tijuca        2      1       0    78
# 32     Apartamento                  Botafogo        2      1       0    76
# 36     Apartamento  Recreio dos Bandeirantes        3      1       1   105
# ...            ...                       ...      ...    ...     ...   ...
# 32934  Apartamento               Jacarepaguá        2      1       1    78
# 32940  Apartamento           Barra da Tijuca        2      1       1    85
# 32941  Apartamento           Barra da Tijuca        3      2       0    98
# 32944  Apartamento  Recreio dos Bandeirantes        3      2       1    88
# 32956  Apartamento               Jacarepaguá        3      1       2    78
#
#         Valor  Condominio   IPTU
# 12     1500.0       455.0   14.0
# ...

# %% [markdown]
# ## Salvando os dados

# %% [markdown]
# - **df.to_csv('nome_do_arquivo', index=False)**: salva um data frame na pasta local sem a coluna de index.

# %%
dados_apartamento.to_csv("dados_apartamentos.csv", sep=";", index=False)

# %%
pd.read_csv('dados_apartamentos.csv', sep=";")
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                Centro        1      0       0    15
# 1      Apartamento          Higienópolis        1      0       0    48
# 2      Apartamento          Vista Alegre        3      1       0    70
# 3      Apartamento              Cachambi        2      0       0    50
# 4      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 19527  Apartamento        Vila Valqueire        2      0       0    52
# 19528  Apartamento                 Méier        2      0       0    70
# 19529  Apartamento           Jacarepaguá        3      1       2    78
# 19530  Apartamento  São Francisco Xavier        2      1       0    48
# 19531  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0       800.0       390.0  20.0
# 1       800.0       230.0   NaN
# ...
